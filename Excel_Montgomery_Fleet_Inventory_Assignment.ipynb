# %% [markdown]
# # _EXCEL_MONTGOMERY_FLEET_EQUIPMENT_INVENTORY_ASSIGNMENT_

# %% [markdown]
# ## _CLEAN AND PREPARE THE DATA_

# %% [markdown]
# ## 1.Remove Empty rows

# %% [markdown]
# ![empty%20rows.png](attachment:empty%20rows.png)

# %% [markdown]
# ### I removed blank rows by this process :
# ### a. Selecting whole dataset (CTRL+SHIFT+END)
# ### b. Clicking on data tab and selecting filter
# ### c. Filter icons will apppear next to column headers
# ### d. Click on any filter icon then uncheck "select all" and check "blanks"
# ### e. You will be left with blank rows now, delete them.

# %% [markdown]
# ![Empty%20rows.png](attachment:Empty%20rows.png)

# %% [markdown]
# ## _I perfectly removed all blank rows._

# %% [markdown]
# ![empty%20rows.png](attachment:empty%20rows.png)

# %% [markdown]
# ## 2.Remove Duplicates

# %% [markdown]
# ###  I find duplicate values by this process:
# ### a) Select desired column where duplicate values are not expected
# ### b) Choose conditional formatting, then Highlight cells rules and then duplicate rows
# ### c) Duplicated values are highlighted now, you can delete unexpected dupicate values.
# ## OR
# ### a) Select whole Dataset(CTRL+SHIFT+END)
# ### b) Click on Data tab and select duplicate values
# ### c) Uncheck "select all " columns and check only desired column.
# ### d) It will delete all duplicate values including expected duplicate values.

# %% [markdown]
# ![Duplicate%20.png](attachment:Duplicate%20.png)

# %% [markdown]
# ## 3. Spelling check

# %% [markdown]
# ### We can check spelling of any column by clicking on it and then clicking on review tab and then on spell checks Or simply click on any column and press F7.

# %% [markdown]
# ## 4. Remove extra whitespaces

# %% [markdown]
# ### To remove extra white spaces:
# ### a) I added helper column
# ### b) used TRIM function and added cell reference , i.e  [Trim(comn_name)]
# ### c) Pasted the values of helper column in the original column and deleted helper column.

# %% [markdown]
# ## 5. _Department names: When the data was converted from its data source, the department names (see correct list below) didn’t import correctly and they are now split over two columns in the data. Reduce the department names to just one column, and then remove any unnecessary columns._

# %% [markdown]
# ![Department.png](attachment:Department.png)

# %% [markdown]
# ## To reduce the department names in just one column:

# %% [markdown]
# ![department.png](attachment:department.png)

# %% [markdown]
# ### a) I made a helper column and named it as "Department Names"
# ### b) I used Concatenate function to add items of two column in just one
# ### example:{=CONCATENATE( A8," ", C8)}
# ### c) Then i deleted unnecessary rows.

# %% [markdown]
# ![Concatenate.png](attachment:Concatenate.png)

# %% [markdown]
# ### _Successfully reduced elements of two columns in just one_

# %% [markdown]
# ![concatenate.png](attachment:concatenate.png)

# %% [markdown]
#  ## _Successfully cleaned the dataset_

# %% [markdown]
# ![Format.png](attachment:Format.png)

# %% [markdown]
# ## Formated Dataset as Table

# %% [markdown]
# # _Successfully cleaned and prepared the Data_

# %% [markdown]
# # ANALYZE THE DATA

# %% [markdown]
# ## 1.Calculate values: find the following values for column ‘C’ and record each of the values:
#
# #### a.SUM
# #### b.AVERAGE
# #### c.MIN
# #### d.MAX
# #### e.COUNT

# %% [markdown]
# ![columnC.png](attachment:columnC.png)

# %% [markdown]
# ## _Calculated the required values and the values are correct_

# %% [markdown]
# ## 2.Create a Pivot Table: Use the PivotTable feature to create a pivot table that displays the Department field in the Rows section, and the Equipment Count in the Values section, so that the pivot table displays the sum of equipment count by department.

# %% [markdown]
# ![Sum%20of%20Equipment.png](attachment:Sum%20of%20Equipment.png)

# %% [markdown]
# ## _Successfully created the Pivot Table that displays the Sum of Equipment count by Department_

# %% [markdown]
# ## 3.Make two more pivot tables exactly the same as task 2: Follow the same steps you performed in Tasks 2 to create two more identical pivot tables so that you end up with 3 worksheets that contain identical pivot tables.

# %% [markdown]
# ## 4. Analyze data in the pivot table: Use the PivotTable Fields pane to manipulate and analyze data in the two copied pivot table as follows:
#
# -  In pivot table 2 add the Equipment Class field below the Department field so that the different vehicle types appear under each department with their respective counts.
#  - Collapse all fields except the top one  Transportation
# - In pivot table 3 add the Equipment Class field above the Department field so that the different vehicle types appear first, with the different departments listed underneath each vehicle type with their respective counts.
#   - Collapse all fields except the top one - CUV

# %% [markdown]
# ![Pivot2.png](attachment:Pivot2.png)

# %% [markdown]
# ## _Pivot Table 2_

# %% [markdown]
# ![Pivot%203.png](attachment:Pivot%203.png)

# %% [markdown]
# ## _Pivot Table 3_

# %% [markdown]
# ## Successfully Completed all the Tasks

# %% [markdown]
# # _I Successfully cleaned, Prepared and Analyzed the Data_

# %% [markdown]
# ### NOTE: Dataset in the cleaning and Analyzing Part of the Assignment were different.

# %% [markdown]
# # END OF AN ASSIGNMENT
